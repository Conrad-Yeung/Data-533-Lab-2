# %%
import Bank.Accounts.Account as AC

dam = AC.Account("Conrad",123)

dam.name
dam.ac
dam.bal
dam.deposit (69)
dam.deposit (70)
dam.deposit (600)
dam.withdraw (10)
dam.deposit (600)
dam.deposit (600)
dam.summary ()
dam.details()
# Out:
# $69.00 has been deposited to account 69692345
# Current balance: $192.00
# $70.00 has been deposited to account 69692345
# Current balance: $262.00
# $600.00 has been deposited to account 69692345
# Current balance: $862.00
# $10.00 has been withdrawn from account 69692345
# Current balance: $852.00
# $600.00 has been deposited to account 69692345
# Current balance: $1452.00
# $600.00 has been deposited to account 69692345
# Current balance: $2052.00
# Account Holder: Conrad
# Current Balance: $2052.00
# Your balance history for the past 30 transcations:
# The account holder is: Conrad
# The account number is: 69692345
# Your current balance is: $2052.00

# %%
dam.ac
# Out:
# 69692345

# %%
import Bank.Accounts.Chequing as ch

cheque = ch.Chequing("Conrad",169)
cheque.deposit(1000)
# Out:
# $1000.00 has been deposited to account 72868543
# Current balance: $1169.00

# %%
cheque.deposit(1000)
# Out:
# $1000.00 has been deposited to account 169
# Current balance: $2000.00

# %%
cheque.withdraw(250)
# Out:
# $250.00 has been withdrawn from account 169
# Current balance: $1750.00

# %%
cheque.summary()
# Out:
# Account Holder: Conrad
# Current Balance: $1169.00
# Your balance history for the past 30 transcations:

# %%
cheque.trans_lim
cheque.withdraw(1001)
cheque.bal
# Out:
# Your current transaction limit is $1000.00, therefore you are unable to withdraw the requested amount of $1001.00.
# 1169

# %%
cheque.deposit(100.0123)
cheque.withdraw(0.01)
# Out:
# $100.01 has been deposited to account 72868543
# Current balance: $1269.01
# $0.01 has been withdrawn from account 72868543
# Current balance: $1269.00

# %%
cheque.details()
# Out:
# The account holder is: Conrad.
# The account number is: 72868543.
# The account type is: Chequings
# Your current balance is: $1269.00.
# Your current transaction limit is: $1000.00.

# %%
import Bank.Accounts.Saving as sv

test = sv.Saving("Yes",1000)
test.details()
# Out:
# The account holder is: Yes.
# The account number is: 17958879.
# The account type is: Savings
# Your current balance is: $1000.00.
# Your current transaction limit is: $1000.00.
# --------------------------------------------
# You currently have no fixed deposits in process.

# %%
test.setfixdeposit(500)
# Out:
# Your deposit of $500.00 has been fixed for a year with an interest rate of 1.00%.
# On 2021/11/28, $505.0 will be added to your Savings account.

# %%
test.setfixdeposit(500)
# Out:
# You already have a fixed deposit in process. The current amount locked in is $500.00 at a rate of 1.00. The amount will be made available on 2021/11/28.

# %%
test.setfixdeposit(1000,0.01,True)
# Out:
# Your fixed depot created on 2020/11/28 is complete.
# $505.00 has been deposited to account 17958879
# Current balance: $1505.00

# %%
test.bal_hist
# Out:
# [1000, 1505.0]

# %%
test.setfixdeposit(10)
# Out:
# Your deposit of $10.00 has been fixed for a year with an interest rate of 1.00%.
# On 2021/11/28, $10.1 will be added to your Savings account.

# %%
test.change_lim(1500)
# Out:
# Your transaction limit has decreased from $1000.00 to $1500.00.

# %%
test.withdraw(1500)
# Out:
# $1500.00 has been withdrawn from account 17958879
# Current balance: $5.00

# %%
test.details()
# Out:
# The account holder is: Yes.
# The account number is: 17958879.
# The account type is: Savings
# Your current balance is: $5.00.
# Your current transaction limit is: $1500.00.
# --------------------------------------------
# You currently have $10.00 fixed at an interest rate of 1.00%
# On 2021/11/28, $10.1 will be added to your Savings account.

# %%
test.summary()
test.deposit(10000000000)
# Out:
# Account Holder: Yes
# Current Balance: $5.00
# Your balance history for the past 30 transcations:
# $10000000000.00 has been deposited to account 17958879
# Current balance: $10000000005.00

# %%
test.summary()
test.details()
# Out:
# Account Holder: Yes
# Current Balance: $10000000005.00
# Your balance history for the past 30 transcations:
# The account holder is: Yes.
# The account number is: 17958879.
# The account type is: Savings
# Your current balance is: $10000000005.00.
# Your current transaction limit is: $1500.00.
# --------------------------------------------
# You currently have $10.00 fixed at an interest rate of 1.00%
# On 2021/11/28, $10.1 will be added to your Savings account.
